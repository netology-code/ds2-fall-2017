# %% [markdown]
# # Алгоритм GrabCut
# http://en.wikipedia.org/wiki/GrabCut

# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Загружаем изображение

# %%
img = cv2.imread('../data/messi5.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Рамкой выделяем область для оценки распределения значений пикселей объекта

# %%
tmp = np.copy(img)
rect = (50,50,450,290)
x1, y1, x2, y2 = rect
tmp = cv2.rectangle(tmp, (x1,y1), (x2,y2),  (0,0,255), 3)

# %%
plt.imshow(cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Запускаем алгоритм GrabCut

# %%
mask_ = mask.copy()

# %%
# mask = np.zeros(img.shape[:2], np.uint8)  # выделяем память под результат работы алгоритма

# выделяем память необходимую для работы алгоритма
bgdModel = np.zeros((1,65), np.float64)
fgdModel = np.zeros((1,65), np.float64)

rect = (50,50,450,290)  # прямоугльником задаем область принадлежащую объекту
cv2.grabCut(img, mask_, None, bgdModel,
            fgdModel, 5, cv2.GC_INIT_WITH_MASK)

mask2 = np.where((mask_==2)|(mask_==0), 0, 1).astype('uint8')
result = img * mask2[:,:,np.newaxis]

#mask_ = np.zeros(img.shape[:2], np.uint8)
mask_ = mask.copy()

# %% [markdown]
# # Выводим результат

# %%
mask2 = np.where((mask_==2)|(mask_==0), 0, 1).astype('uint8')
result = img * mask2[:,:,np.newaxis]
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))

# %%
mask_ = mask2.copy()

# %%
plt.imshow(mask_)
